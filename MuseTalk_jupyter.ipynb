# %% [markdown]
# <a href="https://colab.research.google.com/github/mansoorsd/musetalk/blob/main/MuseTalk_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install huggingface-hub
# Out:
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (0.34.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (1.1.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (2025.8.3)

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/MuseTalk
# %cd /content/MuseTalk

# !pip install -q diffusers==0.27.2 accelerate==0.28.0 omegaconf ffmpeg-python mmpose mmdet gradio
# !pip install -q https://github.com/camenduru/wheels/releases/download/colab2/mmcv-2.1.0-cp310-cp310-linux_x86_64.whl

# !apt -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco.pth -d /content/MuseTalk/models/dwpose -o dw-ll_ucoco.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco_384.onnx -d /content/MuseTalk/models/dwpose -o dw-ll_ucoco_384.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco_384.pth -d /content/MuseTalk/models/dwpose -o dw-ll_ucoco_384.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-mm_ucoco.pth -d /content/MuseTalk/models/dwpose -o dw-mm_ucoco.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ss_ucoco.pth -d /content/MuseTalk/models/dwpose -o dw-ss_ucoco.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-tt_ucoco.pth -d /content/MuseTalk/models/dwpose -o dw-tt_ucoco.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-l_ucoco_256-95bb32f5_20230822.pth -d /content/MuseTalk/models/dwpose -o rtm-l_ucoco_256-95bb32f5_20230822.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-x_ucoco_256-05f5bcb7_20230822.pth -d /content/MuseTalk/models/dwpose -o rtm-x_ucoco_256-05f5bcb7_20230822.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-x_ucoco_384-f5b50679_20230822.pth -d /content/MuseTalk/models/dwpose -o rtm-x_ucoco_384-f5b50679_20230822.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/yolox_l.onnx -d /content/MuseTalk/models/dwpose -o yolox_l.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/face-parse-bisent/79999_iter.pth -d /content/MuseTalk/models/face-parse-bisent -o 79999_iter.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/face-parse-bisent/resnet18-5c106cde.pth -d /content/MuseTalk/models/face-parse-bisent -o resnet18-5c106cde.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/raw/main/musetalk/musetalk.json -d /content/MuseTalk/models/musetalk -o musetalk.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/musetalk/pytorch_model.bin -d /content/MuseTalk/models/musetalk -o pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/raw/main/sd-vae-ft-mse/config.json -d /content/MuseTalk/models/sd-vae-ft-mse -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.bin -d /content/MuseTalk/models/sd-vae-ft-mse -o diffusion_pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.safetensors -d /content/MuseTalk/models/sd-vae-ft-mse -o diffusion_pytorch_model.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/whisper/tiny.pt -d /content/MuseTalk/models/whisper -o tiny.pt

# !python app.py
# Out:
# /content
# fatal: destination path 'MuseTalk' already exists and is not an empty directory.
# /content/MuseTalk
# ERROR: mmcv-2.1.0-cp310-cp310-linux_x86_64.whl is not a supported wheel on this platform.
# aria2 is already the newest version (1.36.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8e361e|OK  |       0B/s|/content/MuseTalk/models/dwpose/dw-ll_ucoco.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 157c7a|OK  |       0B/s|/content/MuseTalk/models/dwpose/dw-ll_ucoco_384.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# da4525|OK  |       0B/s|/content/MuseTalk/models/dwpose/dw-ll_ucoco_384.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 42b1d6|OK  |       0B/s|/content/MuseTalk/models/dwpose/dw-mm_ucoco.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0339a9|OK  |       0B/s|/content/MuseTalk/models/dwpose/dw-ss_ucoco.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 967193|OK  |       0B/s|/content/MuseTalk/models/dwpose/dw-tt_ucoco.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0f883f|OK  |       0B/s|/content/MuseTalk/models/dwpose/rtm-l_ucoco_256-95bb32f5_20230822.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ef0dca|OK  |       0B/s|/content/MuseTalk/models/dwpose/rtm-x_ucoco_256-05f5bcb7_20230822.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 736125|OK  |       0B/s|/content/MuseTalk/models/dwpose/rtm-x_ucoco_384-f5b50679_20230822.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3a05ed|OK  |       0B/s|/content/MuseTalk/models/dwpose/yolox_l.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0f0b96|OK  |       0B/s|/content/MuseTalk/models/face-parse-bisent/79999_iter.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8223cc|OK  |       0B/s|/content/MuseTalk/models/face-parse-bisent/resnet18-5c106cde.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c7f863|OK  |       0B/s|/content/MuseTalk/models/musetalk/musetalk.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 37f960|OK  |       0B/s|/content/MuseTalk/models/musetalk/pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6a2563|OK  |       0B/s|/content/MuseTalk/models/sd-vae-ft-mse/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 00c679|OK  |       0B/s|/content/MuseTalk/models/sd-vae-ft-mse/diffusion_pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# b692bf|OK  |       0B/s|/content/MuseTalk/models/sd-vae-ft-mse/diffusion_pytorch_model.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# dae950|OK  |       0B/s|/content/MuseTalk/models/whisper/tiny.pt
#
# Status Legend:
# (OK):download completed.
# /content/MuseTalk/app.py:379: SyntaxWarning: invalid escape sequence '\*'
#   Yue Zhang <sup>\*</sup>,\
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# Already download the model.
# please download ffmpeg-static and export to FFMPEG_PATH.
# For example: export FFMPEG_PATH=/musetalk/ffmpeg-4.4-amd64-static
# Traceback (most recent call last):
#   File "/content/MuseTalk/app.py", line 118, in <module>
#     from musetalk.utils.utils import get_file_type,get_video_fps,datagen
#   File "/content/MuseTalk/musetalk/utils/utils.py", line 15, in <module>
#     from musetalk.models.vae import VAE
#   File "/content/MuseTalk/musetalk/models/vae.py", line 1, in <module>
#     from diffusers import AutoencoderKL
#   File "/usr/local/lib/python3.12/dist-packages/diffusers/__init__.py", line 5, in <module>
#     from .utils import (
#   File "/usr/local/lib/python3.12/dist-packages/diffusers/utils/__init__.py", line 38, in <module>
#     from .dynamic_modules_utils import get_class_from_dynamic_module
#   File "/usr/local/lib/python3.12/dist-packages/diffusers/utils/dynamic_modules_utils.py", line 28, in <module>
#     from huggingface_hub import cached_download, hf_hub_download, model_info
# ImportError: cannot import name 'cached_download' from 'huggingface_hub' (/usr/local/lib/python3.12/dist-packages/huggingface_hub/__init__.py). Did you mean: 'hf_hub_download'?

# %%
# !python app.py
# Out:
# /content/MuseTalk/app.py:379: SyntaxWarning: invalid escape sequence '\*'
#   Yue Zhang <sup>\*</sup>,\
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# Already download the model.
# please download ffmpeg-static and export to FFMPEG_PATH.
# For example: export FFMPEG_PATH=/musetalk/ffmpeg-4.4-amd64-static
# 2025-09-03 09:33:10.904098: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756891990.924535    8715 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756891990.930718    8715 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756891990.946720    8715 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756891990.946753    8715 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756891990.946756    8715 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756891990.946760    8715 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-03 09:33:10.951607: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/MuseTalk/app.py", line 119, in <module>
#     from musetalk.utils.preprocessing import get_landmark_and_bbox,read_imgs,coord_placeholder,get_bbox_range
#   File "/content/MuseTalk/musetalk/utils/preprocessing.py", line 10, in <module>
#     from mmpose.apis import inference_topdown, init_model
#   File "/usr/local/lib/python3.12/dist-packages/mmpose/__init__.py", line 2, in <module>
#     import mmcv
# ModuleNotFoundError: No module named 'mmcv'

# %%
pip install -r /content/MuseTalk/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 2)) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 3)) (0.23.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 4)) (2.8.0+cu126)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 5)) (0.35.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 6)) (1.10.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 7)) (2.19.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 8)) (2.19.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 9)) (4.12.0.88)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 10)) (0.13.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 11)) (4.56.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 13)) (5.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 14)) (2.32.4)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 17)) (2.3.0)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 18)) (0.2.0)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 19)) (5.43.1)
# Collecting spaces (from -r /content/MuseTalk/requirements.txt (line 20))
#   Downloading spaces-0.40.1-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 21)) (1.0.3)
# Requirement already satisfied: imageio[ffmpeg] in /usr/local/lib/python3.12/dist-packages (from -r /content/MuseTalk/requirements.txt (line 15)) (2.37.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/MuseTalk/requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->-r /content/MuseTalk/requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->-r /content/MuseTalk/requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->-r /content/MuseTalk/requirements.txt (line 5)) (8.7.0)
# Requirement already satisfied: huggingface-hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers->-r /content/MuseTalk/requirements.txt (line 5)) (0.34.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers->-r /content/MuseTalk/requirements.txt (line 5)) (2024.11.6)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from diffusers->-r /content/MuseTalk/requirements.txt (line 5)) (0.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate->-r /content/MuseTalk/requirements.txt (line 6)) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->-r /content/MuseTalk/requirements.txt (line 6)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate->-r /content/MuseTalk/requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (5.29.5)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (1.74.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (0.5.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r /content/MuseTalk/requirements.txt (line 8)) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r /content/MuseTalk/requirements.txt (line 8)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r /content/MuseTalk/requirements.txt (line 8)) (3.1.3)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile->-r /content/MuseTalk/requirements.txt (line 10)) (1.17.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /content/MuseTalk/requirements.txt (line 11)) (0.22.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /content/MuseTalk/requirements.txt (line 11)) (4.67.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->-r /content/MuseTalk/requirements.txt (line 13)) (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r /content/MuseTalk/requirements.txt (line 14)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->-r /content/MuseTalk/requirements.txt (line 14)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r /content/MuseTalk/requirements.txt (line 14)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->-r /content/MuseTalk/requirements.txt (line 14)) (2025.8.3)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (from imageio[ffmpeg]->-r /content/MuseTalk/requirements.txt (line 15)) (0.6.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->-r /content/MuseTalk/requirements.txt (line 17)) (4.9.3)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from ffmpeg-python->-r /content/MuseTalk/requirements.txt (line 18)) (1.0.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (4.10.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.116.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.6.1)
# Requirement already satisfied: gradio-client==1.12.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (1.12.1)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (3.11.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (2.2.2)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (2.11.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.12.10)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.47.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.16.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.35.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.12.1->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (15.0.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from moviepy->-r /content/MuseTalk/requirements.txt (line 21)) (4.4.2)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy->-r /content/MuseTalk/requirements.txt (line 21)) (0.1.12)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (0.45.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile->-r /content/MuseTalk/requirements.txt (line 10)) (2.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->diffusers->-r /content/MuseTalk/requirements.txt (line 5)) (1.1.8)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (0.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (0.4.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r /content/MuseTalk/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r /content/MuseTalk/requirements.txt (line 19)) (1.5.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->-r /content/MuseTalk/requirements.txt (line 13)) (2.7)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->-r /content/MuseTalk/requirements.txt (line 5)) (3.23.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r /content/MuseTalk/requirements.txt (line 13)) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->-r /content/MuseTalk/requirements.txt (line 7)) (0.1.2)
# Downloading spaces-0.40.1-py3-none-any.whl (33 kB)
# Installing collected packages: spaces
# Successfully installed spaces-0.40.1

# %%
# !pip install -U diffusers accelerate transformers
# Out:
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (0.35.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (0.28.0)
# Collecting accelerate
#   Downloading accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.55.4)
# Collecting transformers
#   Downloading transformers-4.56.0-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers) (8.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers) (3.19.1)
# Requirement already satisfied: huggingface-hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers) (0.34.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers) (2.32.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from diffusers) (0.6.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers) (11.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.8.0+cu126)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->diffusers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->diffusers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->diffusers) (1.1.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.4.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Downloading accelerate-1.10.1-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.9/374.9 kB 13.2 MB/s eta 0:00:00
# Downloading transformers-4.56.0-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 118.6 MB/s eta 0:00:00
# Downloading tokenizers-0.22.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 95.5 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers, accelerate
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.4
#     Uninstalling tokenizers-0.21.4:
#       Successfully uninstalled tokenizers-0.21.4
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.55.4
#     Uninstalling transformers-4.55.4:
#       Successfully uninstalled transformers-4.55.4
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.28.0
#     Uninstalling accelerate-0.28.0:
#       Successfully uninstalled accelerate-0.28.0
# Successfully installed accelerate-1.10.1 tokenizers-0.22.0 transformers-4.56.0

# %%
# !pip install mmcv
# Out:
# Collecting mmcv
#   Using cached mmcv-2.2.0.tar.gz (479 kB)
#   Preparing metadata (setup.py) ... done
# Collecting addict (from mmcv)
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting mmengine>=0.3.0 (from mmcv)
#   Using cached mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mmcv) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mmcv) (25.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from mmcv) (11.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from mmcv) (6.0.2)
# Collecting yapf (from mmcv)
#   Using cached yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv) (13.9.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv) (3.1.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv) (4.12.0.88)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf->mmcv) (4.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.3.0->mmcv) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.3.0->mmcv) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv) (1.17.0)
# Using cached mmengine-0.10.7-py3-none-any.whl (452 kB)
# Using cached addict-2.4.0-py3-none-any.whl (3.8 kB)
# Using cached yapf-0.43.0-py3-none-any.whl (256 kB)
# Building wheels for collected packages: mmcv

# %%
# !python app.py
# Out:
# /content/MuseTalk/app.py:379: SyntaxWarning: invalid escape sequence '\*'
#   Yue Zhang <sup>\*</sup>,\
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# Already download the model.
# please download ffmpeg-static and export to FFMPEG_PATH.
# For example: export FFMPEG_PATH=/musetalk/ffmpeg-4.4-amd64-static
# 2025-09-03 09:37:29.743377: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756892249.763117    9875 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756892249.769171    9875 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756892249.785022    9875 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756892249.785056    9875 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756892249.785062    9875 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756892249.785066    9875 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-03 09:37:29.789606: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/MuseTalk/app.py", line 119, in <module>
#     from musetalk.utils.preprocessing import get_landmark_and_bbox,read_imgs,coord_placeholder,get_bbox_range
#   File "/content/MuseTalk/musetalk/utils/preprocessing.py", line 10, in <module>
#     from mmpose.apis import inference_topdown, init_model
#   File "/usr/local/lib/python3.12/dist-packages/mmpose/__init__.py", line 2, in <module>
#     import mmcv
# ModuleNotFoundError: No module named 'mmcv'
